# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
    def Show(self):
        
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end=" ")
                n = n.nref
                
    def RevShow(self):
        print("\n")
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data, "<---",end=" ")
                n = n.pref
    
    def Addifempty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Helo , The LL is not empty .. ! try to add next this node ")
    
    def Addbegin(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref=self.head
            self.head.pref = new_node
            self.head = new_node
            
    def Addend(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref= new_node
            new_node.pref = n

# %%
LL = DLinkedlist()
LL.Addifempty(100)
LL.Addbegin(200)
LL.Addend(300)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 200 <---

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
    def Show(self):
        
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end=" ")
                n = n.nref
                
    def RevShow(self):
        print("\n")
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data, "<---",end=" ")
                n = n.pref
    
    def Addifempty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Helo , The LL is not empty .. ! try to add next this node ")
    
    def Addbegin(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref=self.head
            self.head.pref = new_node
            self.head = new_node
            
    def Addend(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref= new_node
            new_node.pref = n
                            
    def Add_after(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n.nref is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref = new_node
                n.nref = new_node
                
    def Add_before(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node

# %%
LL = DLinkedlist()
LL.Addifempty(100)
LL.Addbegin(200)
LL.Addend(300)
LL.Add_after(2000,200)
#LL.Add_before(1000,2000)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 2000 <--- 200 <---

# %%
LL.Add_before(1000,2000)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 1000 ---> 2000 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 2000 <--- 1000 <--- 200 <---

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
    def Show(self):
        
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end=" ")
                n = n.nref
                
    def RevShow(self):
        print("\n")
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data, "<---",end=" ")
                n = n.pref
    
    def Addifempty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Helo , The LL is not empty .. ! try to add next this node ")
    
    def Addbegin(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref=self.head
            self.head.pref = new_node
            self.head = new_node
            
    def Addend(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref= new_node
            new_node.pref = n
                            
    def Add_after(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n.nref is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref = new_node
                n.nref = new_node
                
    def Add_before(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node        
                
                
    def Del_begin(self):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return
        if self.head.nref is None:
            self.head = None
            print(" One Node aslo Has been deleted ! DDL will is Empty Now")
        else:
            self.head = self.head.nref 
            self.head.pref = None

# %%
LL = DLinkedlist()
LL.Addifempty(100)
LL.Addbegin(200)
LL.Addend(300)
LL.Add_after(2000,200)
#LL.Add_before(1000,2000)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 2000 <--- 200 <---

# %%
LL.Del_begin()
LL.Show()
LL.RevShow()
# Out:
# 100 ---> 300 --->
#
# 300 <--- 100 <---

# %%
LL.Del_begin()
LL.Show()
LL.RevShow()
# Out:
# 300 --->
#
# 300 <---

# %%
LL.Del_begin()
LL.Show()
LL.RevShow()
# Out:
#  One Node aslo Has been deleted ! DDL will is Empty Now
# Sorry , The Linked List is Empty !
#
#
# Sorry , The Linked List is Empty !

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
    def Show(self):
        
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end=" ")
                n = n.nref
                
    def RevShow(self):
        print("\n")
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data, "<---",end=" ")
                n = n.pref
    
    def Addifempty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Helo , The LL is not empty .. ! try to add next this node ")
    
    def Addbegin(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref=self.head
            self.head.pref = new_node
            self.head = new_node
            
    def Addend(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref= new_node
            new_node.pref = n
                            
    def Add_after(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n.nref is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref = new_node
                n.nref = new_node
                
    def Add_before(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node        
                
                
    def Del_begin(self):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return
        if self.head.nref is None:
            self.head = None
            print(" One Node aslo Has been deleted ! DDL will is Empty Now")
        else:
            self.head = self.head.nref 
            self.head.pref = None
            
        
    def Del_end(self):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return  
        if self.head.nref is None:
            self.head = None
            print(" One Node aslo Has been deleted ! DDL will is Empty Now")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.pref.nref = None

# %%
LL = DLinkedlist()
LL.Addifempty(100)
LL.Addbegin(200)
LL.Addend(300)
LL.Add_after(2000,200)
#LL.Add_before(1000,2000)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 2000 <--- 200 <---

# %%
LL.Del_end()
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 100 --->
#
# 100 <--- 2000 <--- 200 <---

# %%
LL.Del_end()
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 --->
#
# 2000 <--- 200 <---

# %%
LL.Del_end()
LL.Show()
LL.RevShow()
# Out:
#  One Node aslo Has been deleted ! DDL will is Empty Now
# Sorry , The Linked List is Empty !
#
#
# Sorry , The Linked List is Empty !

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None

class DLinkedlist:
    def __init__(self):
        self.head = None
        
    def Show(self):
        
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->",end=" ")
                n = n.nref
                
    def RevShow(self):
        print("\n")
        if self.head is None:
            print("Sorry , The Linked List is Empty !")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data, "<---",end=" ")
                n = n.pref
    
    def Addifempty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Helo , The LL is not empty .. ! try to add next this node ")
    
    def Addbegin(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref=self.head
            self.head.pref = new_node
            self.head = new_node
            
    def Addend(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref= new_node
            new_node.pref = n
                            
    def Add_after(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n.nref is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref = new_node
                n.nref = new_node
                
    def Add_before(self,data,x):
        if self.head is None:
            print(" LL is Empty !")
        else:
            n = self.head 
            while n is not None:
                if x==n.data:
                    break
                n=n.nref
            if n is None:
                print("The Given Node is not prasent in the List ")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node        
                
                
    def Del_begin(self):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return
        if self.head.nref is None:
            self.head = None
            print(" One Node aslo Has been deleted ! DDL will is Empty Now")
        else:
            self.head = self.head.nref 
            self.head.pref = None
            
        
    def Del_end(self):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return  
        if self.head.nref is None:
            self.head = None
            print(" One Node aslo Has been deleted ! DDL will is Empty Now")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.pref.nref = None
        
        
        
    def Del_any_where(self,x):
        if self.head is None:
            Print("DLL is Empty , We can't perform Delete Operation !")
            return  
        if self.head.nref is None:
            if x == self.head.data:
                self.head = None
            else:
                print("Node is not present in the list")
            return 
        if self.head.data ==x:
            self.head = self.head.nref
            self.head.pref = None
            return 
        n = self.head
        while n.nref is not None:
            if x == n.data:
                break
            n = n.nref
        if n.nref is not None:
            n.nref.pref = n.pref
            n.pref.nref = n.nref 
        else:
            if n.data == x :
                 n.pref.nref = None
            else:
                 print("please try again ! node is not avelable")

# %%
LL = DLinkedlist()
LL.Addifempty(100)
LL.Addbegin(200)
LL.Addend(300)
LL.Add_after(2000,200)
#LL.Add_before(1000,2000)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 100 ---> 300 --->
#
# 300 <--- 100 <--- 2000 <--- 200 <---

# %%
LL.Del_any_where(100)
LL.Show()
LL.RevShow()
# Out:
# 200 ---> 2000 ---> 300 --->
#
# 300 <--- 2000 <--- 200 <---

# %%
LL.Del_any_where(200)
LL.Show()
LL.RevShow()
# Out:
# 2000 ---> 300 --->
#
# 300 <--- 2000 <---

# %%
LL.Del_any_where(2000)
LL.Show()
LL.RevShow()
# Out:
# 300 --->
#
# 300 <---

# %%
LL.Del_any_where(300)
LL.Show()
LL.RevShow()
# Out:
# Sorry , The Linked List is Empty !
#
#
# Sorry , The Linked List is Empty !
