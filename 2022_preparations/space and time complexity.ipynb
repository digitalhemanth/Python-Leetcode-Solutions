# %%
def prints():
    for i in lists:
        print(i)
        
        
lists = [99,88,77]

prints()
# Out:
# 99
# 88
# 77

# %%
# %timeit prints()
# Out:
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# 77
# 99
# 88
# ...

# %%
My_str = 'Hemanth is a Data scientist'

# %%
import sys

# %%
sys.getsizeof(My_str)
# Out:
# 76

# %%
sys.getsizeof(prints)
# Out:
# 136
